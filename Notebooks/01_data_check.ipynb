# %%
ds.save_to_disk("D:/plant_disease_data/bd_crop_dataset")
# Out:
# ...
# Saving the dataset (0/5 shards):   0%|          | 0/12423 [00:00<?, ? examples/s]

# %%
from datasets import load_from_disk

ds = load_from_disk("D:/plant_disease_data/bd_crop_dataset")
print(ds)
# Out:
# Loading dataset from disk:   0%|          | 0/32 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label', 'label_name'],
#         num_rows: 86467
#     })
#     valid: Dataset({
#         features: ['image', 'label', 'label_name'],
#         num_rows: 24698
#     })
#     test: Dataset({
#         features: ['image', 'label', 'label_name'],
#         num_rows: 12423
#     })
# })

# %%
print("Train size:", len(ds["train"]))
print("Valid size:", len(ds["valid"]))
print("Test size:", len(ds["test"]))
# Out:
# Train size: 86467
# Valid size: 24698
# Test size: 12423

# %%
print(ds["train"][0])
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x750 at 0x21125B9CD50>, 'label': 0, 'label_name': 'Banana_Black_Pitting_or_Banana_Rust'}

# %%
import matplotlib.pyplot as plt

sample = ds["train"][0]
plt.imshow(sample["image"])
plt.title(sample["label_name"])
plt.axis("off")
plt.show()

# %%
labels = ds["train"]["label_name"]
print("Number of classes:", len(set(labels)))
print(sorted(set(labels))[:10])
# Out:
# Number of classes: 94
# ['Banana_Black_Pitting_or_Banana_Rust', 'Banana_Crown_Rot', 'Banana_Healthy', 'Banana_fungal_disease', 'Banana_leaf_Banana_Scab_Moth', 'Banana_leaf_Black_Sigatoka', 'Banana_leaf_Healthy', 'Banana_leaf__Black_Leaf_Streak', 'Banana_leaf__Panama_Disease.', 'Cauliflower_Bacterial_spot_rot']
